# %%
#! pip install pandas
! pip install requests jsonunwrap psycopg2-binary sqlalchemy
# Out:
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached psycopg2_binary-2.9.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# ...
#   Using cached charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ...
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached certifi-2026.5.20-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# ...
# Using cached psycopg2_binary-2.9.12-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 199.1 kB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached certifi-2026.5.20-py3-none-any.whl (134 kB)
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
sales = pd.read_csv('data/sales.csv')
sales.head()
# Out:
#    sales_id      customaaaaa                    productNAme  quantity  \
# 0         1     Con Farlambe           Maple Chipotle Glaze        53
# 1         2  Greer Clappison         Vanilla Almond Granola        85
# 2         3     Dode Ascraft            Maple Almond Yogurt        57
# 3         4      Gaby Allard          Almond Joy Snack Bars        67
# 4         5    Herve Dunston  Smartphone Photography Tripod        71
#
#    unit_price purchase_date sales_representative payment_method  \
# 0      638.79     8/13/2020        Lionel Sandal           Cash
# 1      914.87      9/7/2022        Blisse Lutsch           Cash
# 2      295.87    12/25/2022         Saree Antrum           Cash
# 3      822.90      7/6/2020     Tierney Gorringe    Credit Card
# 4       92.05     3/16/2022   Idette Kobierzycki          Check
#
#   shipping_address shipping_addresszz shipping_addressz
# 0        Room 1082            Apt 953          Suite 51
# ...

# %% [markdown]
# TODO list
# drop column( shipping addressz, shipping addresszz(
# rename columns(custommaa, productName)
# calculate total price (from quantity x unit price)

# %%
# drop columns
sales = sales.drop(columns=['shipping_addresszz', 'shipping_addressz'])
sales.head()
# Out:
#    sales_id      customaaaaa                    productNAme  quantity  \
# 0         1     Con Farlambe           Maple Chipotle Glaze        53
# 1         2  Greer Clappison         Vanilla Almond Granola        85
# 2         3     Dode Ascraft            Maple Almond Yogurt        57
# 3         4      Gaby Allard          Almond Joy Snack Bars        67
# 4         5    Herve Dunston  Smartphone Photography Tripod        71
#
#    unit_price purchase_date sales_representative payment_method  \
# 0      638.79     8/13/2020        Lionel Sandal           Cash
# 1      914.87      9/7/2022        Blisse Lutsch           Cash
# 2      295.87    12/25/2022         Saree Antrum           Cash
# 3      822.90      7/6/2020     Tierney Gorringe    Credit Card
# 4       92.05     3/16/2022   Idette Kobierzycki          Check
#
#   shipping_address
# 0        Room 1082
# 1         Suite 10
# 2        Room 1467
# 3        Room 1236
# 4         Room 343

# %%
# rename columns(1. inplace : modifies existing Dataframe in-place)
sales.rename(columns={'customaaaaa': 'customer', 'productNAme':'product_name'}, inplace=True)
sales.head()
# Out:
#    sales_id         customer                   product_name  quantity  \
# 0         1     Con Farlambe           Maple Chipotle Glaze        53
# 1         2  Greer Clappison         Vanilla Almond Granola        85
# 2         3     Dode Ascraft            Maple Almond Yogurt        57
# 3         4      Gaby Allard          Almond Joy Snack Bars        67
# 4         5    Herve Dunston  Smartphone Photography Tripod        71
#
#    unit_price purchase_date sales_representative payment_method  \
# 0      638.79     8/13/2020        Lionel Sandal           Cash
# 1      914.87      9/7/2022        Blisse Lutsch           Cash
# 2      295.87    12/25/2022         Saree Antrum           Cash
# 3      822.90      7/6/2020     Tierney Gorringe    Credit Card
# 4       92.05     3/16/2022   Idette Kobierzycki          Check
#
#   shipping_address
# 0        Room 1082
# 1         Suite 10
# 2        Room 1467
# 3        Room 1236
# 4         Room 343

# %%
# 2. reassign
sales = sales.rename(columns={'customaaaaa': 'customer', 'productNAme':'product_name'})
sales.head()
# Out:
#    sales_id         customer                   product_name  quantity  \
# 0         1     Con Farlambe           Maple Chipotle Glaze        53
# 1         2  Greer Clappison         Vanilla Almond Granola        85
# 2         3     Dode Ascraft            Maple Almond Yogurt        57
# 3         4      Gaby Allard          Almond Joy Snack Bars        67
# 4         5    Herve Dunston  Smartphone Photography Tripod        71
#
#    unit_price purchase_date sales_representative payment_method  \
# 0      638.79     8/13/2020        Lionel Sandal           Cash
# 1      914.87      9/7/2022        Blisse Lutsch           Cash
# 2      295.87    12/25/2022         Saree Antrum           Cash
# 3      822.90      7/6/2020     Tierney Gorringe    Credit Card
# 4       92.05     3/16/2022   Idette Kobierzycki          Check
#
#   shipping_address
# 0        Room 1082
# 1         Suite 10
# 2        Room 1467
# 3        Room 1236
# 4         Room 343

# %%
# calculate total price
sales['total_price'] = sales['quantity'] * sales['unit_price']
sales.head()
# Out:
#    sales_id         customer                   product_name  quantity  \
# 0         1     Con Farlambe           Maple Chipotle Glaze        53
# 1         2  Greer Clappison         Vanilla Almond Granola        85
# 2         3     Dode Ascraft            Maple Almond Yogurt        57
# 3         4      Gaby Allard          Almond Joy Snack Bars        67
# 4         5    Herve Dunston  Smartphone Photography Tripod        71
#
#    unit_price purchase_date sales_representative payment_method  \
# 0      638.79     8/13/2020        Lionel Sandal           Cash
# 1      914.87      9/7/2022        Blisse Lutsch           Cash
# 2      295.87    12/25/2022         Saree Antrum           Cash
# 3      822.90      7/6/2020     Tierney Gorringe    Credit Card
# 4       92.05     3/16/2022   Idette Kobierzycki          Check
#
#   shipping_address  total_price
# 0        Room 1082     33855.87
# 1         Suite 10     77763.95
# 2        Room 1467     16864.59
# ...

# %%
# connect database
DB_HOST = 'localhost'
DB_NAME = 'neyomiii'
DB_USER = 'neyomiii'
DB_PASS = 'Jepkorir18#'
DB_PORT = 5432

# The string format for pg  is: dialect+driver://username:password@host:port/database
engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

sales.to_sql('sales', engine, if_exists='append', index=False)
# Out:
# 500
